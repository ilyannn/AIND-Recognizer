# %% [markdown]
# # Artificial Intelligence Engineer Nanodegree - Probabilistic Models
# ## Project: Sign Language Recognition System
# - [Introduction](#intro)
# - [Part 1 Feature Selection](#part1_tutorial)
#     - [Tutorial](#part1_tutorial)
#     - [Features Submission](#part1_submission)
#     - [Features Unittest](#part1_test)
# - [Part 2 Train the models](#part2_tutorial)
#     - [Tutorial](#part2_tutorial)
#     - [Model Selection Score Submission](#part2_submission)
#     - [Model Score Unittest](#part2_test)
# - [Part 3 Build a Recognizer](#part3_tutorial)
#     - [Tutorial](#part3_tutorial)
#     - [Recognizer Submission](#part3_submission)
#     - [Recognizer Unittest](#part3_test)
# - [Part 4 (OPTIONAL) Improve the WER with Language Models](#part4_info)

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
# The overall goal of this project is to build a word recognizer for American Sign Language video sequences, demonstrating the power of probabalistic models.  In particular, this project employs  [hidden Markov models (HMM's)](https://en.wikipedia.org/wiki/Hidden_Markov_model) to analyze a series of measurements taken from videos of American Sign Language (ASL) collected for research (see the [RWTH-BOSTON-104 Database](http://www-i6.informatik.rwth-aachen.de/~dreuw/database-rwth-boston-104.php)).  In this video, the right-hand x and y locations are plotted as the speaker signs the sentence.
# [![ASLR demo](http://www-i6.informatik.rwth-aachen.de/~dreuw/images/demosample.png)](https://drive.google.com/open?id=0B_5qGuFe-wbhUXRuVnNZVnMtam8)
#
# The raw data, train, and test sets are pre-defined.  You will derive a variety of feature sets (explored in Part 1), as well as implement three different model selection criterion to determine the optimal number of hidden states for each word model (explored in Part 2). Finally, in Part 3 you will implement the recognizer and compare the effects the different combinations of feature sets and model selection criteria.
#
# At the end of each Part, complete the submission cells with implementations, answer all questions, and pass the unit tests.  Then submit the completed notebook for review!

# %%
import numpy as np
import pandas as pd
from asl_data import AslDb


asl = AslDb() # initializes the database
asl.df.head() # displays the first five rows of the asl database, indexed by video and frame
# Out:
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1

# %% [markdown]
# <a id='part1_tutorial'></a>
# ## PART 1: Data
#
# ### Features Tutorial
# ##### Load the initial database
# A data handler designed for this database is provided in the student codebase as the `AslDb` class in the `asl_data` module.  This handler creates the initial [pandas](http://pandas.pydata.org/pandas-docs/stable/) dataframe from the corpus of data included in the `data` directory as well as dictionaries suitable for extracting data in a format friendly to the [hmmlearn](https://hmmlearn.readthedocs.io/en/latest/) library.  We'll use those to create models in Part 2.
#
# To start, let's set up the initial database and select an example set of features for the training set.  At the end of Part 1, you will create additional feature sets for experimentation.

# %%
asl.df.ix[98,1]  # look at the data available for an individual frame
# Out:
# <ipython-input-2-69a2f7152b97>:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   asl.df.ix[98,1]  # look at the data available for an individual frame
# left-x         149
# left-y         181
# right-x        170
# right-y        175
# nose-x         161
# nose-y          62
# speaker    woman-1
# Name: (98, 1), dtype: object

# %% [markdown]
# The frame represented by video 98, frame 1 is shown here:
# ![Video 98](http://www-i6.informatik.rwth-aachen.de/~dreuw/database/rwth-boston-104/overview/images/orig/098-start.jpg)

# %% [markdown]
# ##### Feature selection for training the model
# The objective of feature selection when training a model is to choose the most relevant variables while keeping the model as simple as possible, thus reducing training time.  We can use the raw features already provided or derive our own and add columns to the pandas dataframe `asl.df` for selection. As an example, in the next cell a feature named `'grnd-ry'` is added. This feature is the difference between the right-hand y value and the nose y value, which serves as the "ground" right y value.

# %%
asl.df['grnd-ry'] = asl.df['right-y'] - asl.df['nose-y']
asl.df.head()  # the new feature 'grnd-ry' is now in the frames dictionary
# Out:
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker  \
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1
#
#              grnd-ry
# video frame
# 98    0          113
#       1          113
#       2          113
#       3          113
#       4          113

# %% [markdown]
# ##### Try it!

# %%
from asl_utils import test_features_tryit
# TODO add df columns for 'grnd-rx', 'grnd-ly', 'grnd-lx' representing differences between hand and nose locations
asl.df['grnd-rx'] = asl.df['right-x'] - asl.df['nose-x']
asl.df['grnd-ly'] = asl.df['left-y']  - asl.df['nose-y']
asl.df['grnd-lx'] = asl.df['left-x']  - asl.df['nose-x']


# test the code
test_features_tryit(asl)
# Out:
# asl.df sample
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker  \
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1
#
#              grnd-ry  grnd-rx  grnd-ly  grnd-lx
# video frame
# 98    0          113        9      119      -12
#       1          113        9      119      -12
#       2          113        9      119      -12
#       3          113        9      119      -12
#       4          113        9      119      -12
# /Users/in/Code/aind/AIND-Recognizer/asl_utils.py:93: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = asl.df.ix[98, 1][GROUND_FEATURES].tolist()
# <font color=green>Correct!</font><br/>

# %%
# collect the features into a list
features_ground = ['grnd-rx','grnd-ry','grnd-lx','grnd-ly']
 #show a single set of features for a given (video, frame) tuple
[asl.df.ix[98,1][v] for v in features_ground]
# Out:
# <ipython-input-5-18b11a1f22bb>:4: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   [asl.df.ix[98,1][v] for v in features_ground]
# [9, 113, -12, 119]

# %% [markdown]
# ##### Build the training set
# Now that we have a feature list defined, we can pass that list to the `build_training` method to collect the features for all the words in the training set.  Each word in the training set has multiple examples from various videos.  Below we can see the unique words that have been loaded into the training set:

# %%
training = asl.build_training(features_ground)
print("Training words: {}".format(training.words))
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Training words: ['JOHN', 'WRITE', 'HOMEWORK', 'IX-1P', 'SEE', 'YESTERDAY', 'IX', 'LOVE', 'MARY', 'CAN', 'GO', 'GO1', 'FUTURE', 'GO2', 'PARTY', 'FUTURE1', 'HIT', 'BLAME', 'FRED', 'FISH', 'WONT', 'EAT', 'BUT', 'CHICKEN', 'VEGETABLE', 'CHINA', 'PEOPLE', 'PREFER', 'BROCCOLI', 'LIKE', 'LEAVE', 'SAY', 'BUY', 'HOUSE', 'KNOW', 'CORN', 'CORN1', 'THINK', 'NOT', 'PAST', 'LIVE', 'CHICAGO', 'CAR', 'SHOULD', 'DECIDE', 'VISIT', 'MOVIE', 'WANT', 'SELL', 'TOMORROW', 'NEXT-WEEK', 'NEW-YORK', 'LAST-WEEK', 'WILL', 'FINISH', 'ANN', 'READ', 'BOOK', 'CHOCOLATE', 'FIND', 'SOMETHING-ONE', 'POSS', 'BROTHER', 'ARRIVE', 'HERE', 'GIVE', 'MAN', 'NEW', 'COAT', 'WOMAN', 'GIVE1', 'HAVE', 'FRANK', 'BREAK-DOWN', 'SEARCH-FOR', 'WHO', 'WHAT', 'LEG', 'FRIEND', 'CANDY', 'BLUE', 'SUE', 'BUY1', 'STOLEN', 'OLD', 'STUDENT', 'VIDEOTAPE', 'BORROW', 'MOTHER', 'POTATO', 'TELL', 'BILL', 'THROW', 'APPLE', 'NAME', 'SHOOT', 'SAY-1P', 'SELF', 'GROUP', 'JANA', 'TOY1', 'MANY', 'TOY', 'ALL', 'BOY', 'TEACHER', 'GIRL', 'BOX', 'GIVE2', 'GIVE3', 'GET', 'PUTASIDE']

# %% [markdown]
# The training data in `training` is an object of class `WordsData` defined in the `asl_data` module.  in addition to the `words` list, data can be accessed with the `get_all_sequences`, `get_all_Xlengths`, `get_word_sequences`, and `get_word_Xlengths` methods. We need the `get_word_Xlengths` method to train multiple sequences with the `hmmlearn` library.  In the following example, notice that there are two lists; the first is a concatenation of all the sequences(the X portion) and the second is a list of the sequence lengths(the Lengths portion).

# %%
training.get_word_Xlengths('CHOCOLATE')
# Out:
# (array([[-11,  48,   7, 120],
#         [-11,  48,   8, 109],
#         [ -8,  49,  11,  98],
#         [ -7,  50,   7,  87],
#         [ -4,  54,   7,  77],
#         [ -4,  54,   6,  69],
#         [ -4,  54,   6,  69],
#         [-13,  52,   6,  69],
#         [-13,  52,   6,  69],
#         [ -8,  51,   6,  69],
#         [ -8,  51,   6,  69],
#         [ -8,  51,   6,  69],
#         [ -8,  51,   6,  69],
#         [ -8,  51,   6,  69],
#         [-10,  59,   7,  71],
#         [-15,  64,   9,  77],
#         [-17,  75,  13,  81],
#         [ -4,  48,  -4, 113],
#         [ -2,  53,  -4, 113],
#         [ -4,  55,   2,  98],
#         [ -4,  58,   2,  98],
#         [ -1,  59,   2,  89],
#         [ -1,  59,  -1,  84],
#         [ -1,  59,  -1,  84],
#         [ -7,  63,  -1,  84],
#         [ -7,  63,  -1,  84],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -7,  63,   3,  83],
#         [ -4,  70,   3,  83],
#         [ -4,  70,   3,  83],
#         [ -2,  73,   5,  90],
#         [ -3,  79,  -4,  96],
#         [-15,  98,  13, 135],
#         [ -6,  93,  12, 128],
#         [ -2,  89,  14, 118],
#         [  5,  90,  10, 108],
#         [  4,  86,   7, 105],
#         [  4,  86,   7, 105],
#         [  4,  86,  13, 100],
#         [ -3,  82,  14,  96],
#         [ -3,  82,  14,  96],
#         [  6,  89,  16, 100],
#         [  6,  89,  16, 100],
#         [  7,  85,  17, 111]]), [17, 20, 12])

# %% [markdown]
# ###### More feature sets
# So far we have a simple feature set that is enough to get started modeling.  However, we might get better results if we manipulate the raw values a bit more, so we will go ahead and set up some other options now for experimentation later.  For example, we could normalize each speaker's range of motion with grouped statistics using [Pandas stats](http://pandas.pydata.org/pandas-docs/stable/api.html#api-dataframe-stats) functions and [pandas groupby](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html).  Below is an example for finding the means of all speaker subgroups.

# %%
df_means = asl.df.groupby('speaker').mean()
df_means
# Out:
#              left-x      left-y     right-x     right-y      nose-x  \
# speaker
# man-1    206.248203  218.679449  155.464350  150.371031  175.031756
# woman-1  164.661438  161.271242  151.017865  117.332462  162.655120
# woman-2  183.214509  176.527232  156.866295  119.835714  170.318973
#
#             nose-y    grnd-ry    grnd-rx     grnd-ly    grnd-lx
# speaker
# man-1    61.642600  88.728430 -19.567406  157.036848  31.216447
# woman-1  57.245098  60.087364 -11.637255  104.026144   2.006318
# woman-2  58.022098  61.813616 -13.452679  118.505134  12.895536

# %% [markdown]
# To select a mean that matches by speaker, use the pandas [map](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.map.html) method:

# %%
asl.df['left-x-mean']= asl.df['speaker'].map(df_means['left-x'])
asl.df.head()
# Out:
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker  \
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1
#
#              grnd-ry  grnd-rx  grnd-ly  grnd-lx  left-x-mean
# video frame
# 98    0          113        9      119      -12   164.661438
#       1          113        9      119      -12   164.661438
#       2          113        9      119      -12   164.661438
#       3          113        9      119      -12   164.661438
#       4          113        9      119      -12   164.661438

# %% [markdown]
# ##### Try it!

# %%
from asl_utils import test_std_tryit
# TODO Create a dataframe named `df_std` with standard deviations grouped by speaker
df_std = asl.df.groupby('speaker').std()

# test the code
test_std_tryit(df_std)
# Out:
# df_std
#             left-x     left-y    right-x    right-y    nose-x    nose-y  \
# speaker
# man-1    15.154425  36.328485  18.901917  54.902340  6.654573  5.520045
# woman-1  17.573442  26.594521  16.459943  34.667787  3.549392  3.538330
# woman-2  15.388711  28.825025  14.890288  39.649111  4.099760  3.416167
#
#            grnd-ry    grnd-rx    grnd-ly    grnd-lx  left-x-mean
# speaker
# man-1    53.487999  20.269032  36.572749  15.080360          0.0
# woman-1  33.972660  16.764706  27.117393  17.328941          0.0
# woman-2  39.128572  16.191324  29.320655  15.050938          0.0
# /Users/in/Code/aind/AIND-Recognizer/asl_utils.py:102: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = df_std.ix['man-1'][RAW_FEATURES]
# <font color=green>Correct!</font><br/>

# %% [markdown]
# <a id='part1_submission'></a>
# ### Features Implementation Submission
# Implement four feature sets and answer the question that follows.
# - normalized Cartesian coordinates
#     - use *mean* and *standard deviation* statistics and the [standard score](https://en.wikipedia.org/wiki/Standard_score) equation to account for speakers with different heights and arm length
#
# - polar coordinates
#     - calculate polar coordinates with [Cartesian to polar equations](https://en.wikipedia.org/wiki/Polar_coordinate_system#Converting_between_polar_and_Cartesian_coordinates)
#     - use the [np.arctan2](https://docs.scipy.org/doc/numpy-1.10.0/reference/generated/numpy.arctan2.html) function and *swap the x and y axes* to move the $0$ to $2\pi$ discontinuity to 12 o'clock instead of 3 o'clock;  in other words, the normal break in radians value from $0$ to $2\pi$ occurs directly to the left of the speaker's nose, which may be in the signing area and interfere with results.  By swapping the x and y axes, that discontinuity move to directly above the speaker's head, an area not generally used in signing.
#
# - delta difference
#     - as described in Thad's lecture, use the difference in values between one frame and the next frames as features
#     - pandas [diff method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.diff.html) and [fillna method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html) will be helpful for this one
#
# - custom features
#     - These are your own design; combine techniques used above or come up with something else entirely. We look forward to seeing what you come up with!
#     Some ideas to get you started:
#         - normalize using a [feature scaling equation](https://en.wikipedia.org/wiki/Feature_scaling)
#         - normalize the polar coordinates
#         - adding additional deltas

# %%
# TODO add features for normalized by speaker values of left, right, x, y
# Name these 'norm-rx', 'norm-ry', 'norm-lx', and 'norm-ly'
# using Z-score scaling (X-Xmean)/Xstd

features_norm = ['norm-rx', 'norm-ry', 'norm-lx','norm-ly']
sources = ['right-x', 'right-y', 'left-x', 'left-y']

for feature, source in zip(features_norm, sources):
    mean = asl.df['speaker'].map(df_means[source])
    std = asl.df['speaker'].map(df_std[source])
    asl.df[feature] = (asl.df[source] - mean) / std

asl.df.head()
# Out:
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker  \
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1
#
#              grnd-ry  grnd-rx  grnd-ly  grnd-lx  left-x-mean   norm-rx  \
# video frame
# 98    0          113        9      119      -12   164.661438  1.153232
#       1          113        9      119      -12   164.661438  1.153232
#       2          113        9      119      -12   164.661438  1.153232
#       3          113        9      119      -12   164.661438  1.153232
#       4          113        9      119      -12   164.661438  1.153232
#
#               norm-ry   norm-lx   norm-ly
# video frame
# 98    0      1.663433 -0.891199  0.741835
#       1      1.663433 -0.891199  0.741835
#       2      1.663433 -0.891199  0.741835
#       3      1.663433 -0.891199  0.741835
#       4      1.663433 -0.891199  0.741835

# %%
# TODO add features for polar coordinate values where the nose is the origin
# Name these 'polar-rr', 'polar-rtheta', 'polar-lr', and 'polar-ltheta'
# Note that 'polar-rr' and 'polar-rtheta' refer to the radius and angle

features_polar = ['polar-rr', 'polar-rtheta', 'polar-lr', 'polar-ltheta']

for lr in ['l', 'r']:
    x = asl.df['grnd-'+lr+'x'] 
    y = asl.df['grnd-'+lr+'y'] 
    asl.df['polar-'+lr+'r'] = np.sqrt(x * x + y * y)
    asl.df['polar-'+lr+'theta'] = np.arctan2(x, y)
    
asl.df.head()
# Out:
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker  \
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1
#
#              grnd-ry  grnd-rx  grnd-ly  grnd-lx  left-x-mean   norm-rx  \
# video frame
# 98    0          113        9      119      -12   164.661438  1.153232
#       1          113        9      119      -12   164.661438  1.153232
#       2          113        9      119      -12   164.661438  1.153232
#       3          113        9      119      -12   164.661438  1.153232
#       4          113        9      119      -12   164.661438  1.153232
#
#               norm-ry   norm-lx   norm-ly    polar-lr  polar-ltheta  \
# video frame
# 98    0      1.663433 -0.891199  0.741835  119.603512     -0.100501
#       1      1.663433 -0.891199  0.741835  119.603512     -0.100501
#       2      1.663433 -0.891199  0.741835  119.603512     -0.100501
#       3      1.663433 -0.891199  0.741835  119.603512     -0.100501
#       4      1.663433 -0.891199  0.741835  119.603512     -0.100501
#
#               polar-rr  polar-rtheta
# video frame
# 98    0      113.35784      0.079478
#       1      113.35784      0.079478
#       2      113.35784      0.079478
#       3      113.35784      0.079478
#       4      113.35784      0.079478

# %%
# TODO add features for left, right, x, y differences by one time step, i.e. the "delta" values discussed in the lecture
# Name these 'delta-rx', 'delta-ry', 'delta-lx', and 'delta-ly'

features_delta = ['delta-rx', 'delta-ry', 'delta-lx', 'delta-ly']

for leftright in ['left', 'right']:
    lr = leftright[0]
    for xy in ['x', 'y']:
        asl.df['delta-'+lr+xy] = asl.df[leftright+'-'+xy].diff().fillna(0)

# %%
# TODO add features of your own design, which may be a combination of the above or something else
# Name these whatever you would like

df_means = asl.df.groupby('speaker').mean()
df_std = asl.df.groupby('speaker').std()

features_custom = ['distn-rn', 'distn-ln', 'distn-x', 'distn-y']

asl.df['distance-rl-y'] = asl.df['right-y'] - asl.df['left-y']
asl.df['distance-rl-x'] = asl.df['right-x'] - asl.df['left-x']

sources = ['polar-rr', 'polar-lr', 'distance-rl-x', 'distance-rl-y']

for (feature, source) in zip(features_custom, sources):

    mean = asl.df['speaker'].map(df_means[source])
    std = asl.df['speaker'].map(df_std[source])

    asl.df[feature] = (asl.df[source] - mean) / std

asl.df.head()
# asl.df.ix[98,1]
# Out:
#              left-x  left-y  right-x  right-y  nose-x  nose-y  speaker  \
# video frame
# 98    0         149     181      170      175     161      62  woman-1
#       1         149     181      170      175     161      62  woman-1
#       2         149     181      170      175     161      62  woman-1
#       3         149     181      170      175     161      62  woman-1
#       4         149     181      170      175     161      62  woman-1
#
#              grnd-ry  grnd-rx  grnd-ly  ...  delta-lx  delta-ly  delta-rx  \
# video frame                             ...
# 98    0          113        9      119  ...       0.0       0.0       0.0
#       1          113        9      119  ...       0.0       0.0       0.0
#       2          113        9      119  ...       0.0       0.0       0.0
#       3          113        9      119  ...       0.0       0.0       0.0
#       4          113        9      119  ...       0.0       0.0       0.0
#
#              delta-ry  distance-rl-y  distance-rl-x  distn-rn  distn-ln  \
# video frame
# 98    0           0.0             -6             21  1.573439  0.542499
#       1           0.0             -6             21  1.573439  0.542499
#       2           0.0             -6             21  1.573439  0.542499
#       3           0.0             -6             21  1.573439  0.542499
#       4           0.0             -6             21  1.573439  0.542499
#
#               distn-x   distn-y
# video frame
# 98    0      1.196372  1.012756
#       1      1.196372  1.012756
#       2      1.196372  1.012756
#       3      1.196372  1.012756
#       4      1.196372  1.012756
#
# [5 rows x 30 columns]

# %% [markdown]
# **Question 1:**  What custom features did you choose for the features_custom set and why?
#
# **Answer 1:**
#  I have selected the values that represent the three intervals between the points that are available to us, that is, nose-left hand, nose-right hand and the left-right hand segments. Those values are additionally normalized per-speaker. Note that:
#
#  - The intervals to the nose are represented only by their lengths. `distn-rn` and `distn-ln` are therefore produced from `polar-rr`, `polar-lr`. The rationale is that to the humans is doesn't seem likely to be important whether the hard is exactly below the nose or a bit off.
#
#  - The interval between the hands is represented with two coordinate values, `distn-x`, `distn-y`. The rationale is that in a gesture with one hand slightly above the other that fact would be likely noticeable to the observing human. Is is expected that including both coordinates will therefore improve the quality of recognition.
#
# If we examine closely the geometry, we see that those 4 values allow us to reconstruct almost completely the 3 points (6 degrees of freedom of those points = 4 values + 2 shifts of the whole picture); any other data would be mostly redundant from the theoretical point of view (but, of course, could be useful in practice). This choice therefore seems reasonable.

# %% [markdown]
# <a id='part1_test'></a>
# ### Features Unit Testing
# Run the following unit tests as a sanity check on the defined "ground", "norm", "polar", and 'delta"
# feature sets.  The test simply looks for some valid values but is not exhaustive.  However, the project should not be submitted if these tests don't pass.

# %%
import unittest
# import numpy as np

class TestFeatures(unittest.TestCase):

    def test_features_ground(self):
        sample = (asl.df.ix[98, 1][features_ground]).tolist()
        self.assertEqual(sample, [9, 113, -12, 119])

    def test_features_norm(self):
        sample = (asl.df.ix[98, 1][features_norm]).tolist()
        np.testing.assert_almost_equal(sample, [ 1.153,  1.663, -0.891,  0.742], 3)

    def test_features_polar(self):
        sample = (asl.df.ix[98,1][features_polar]).tolist()
        np.testing.assert_almost_equal(sample, [113.3578, 0.0794, 119.603, -0.1005], 3)

    def test_features_delta(self):
        sample = (asl.df.ix[98, 0][features_delta]).tolist()
        self.assertEqual(sample, [0, 0, 0, 0])
        sample = (asl.df.ix[98, 18][features_delta]).tolist()
        self.assertTrue(sample in [[-16, -5, -2, 4], [-14, -9, 0, 0]], "Sample value found was {}".format(sample))
                         
suite = unittest.TestLoader().loadTestsFromModule(TestFeatures())
unittest.TextTestRunner().run(suite)
# Out:
# <ipython-input-17-1636f2224f9f>:19: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = (asl.df.ix[98, 0][features_delta]).tolist()
# <ipython-input-17-1636f2224f9f>:21: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = (asl.df.ix[98, 18][features_delta]).tolist()
# .<ipython-input-17-1636f2224f9f>:7: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = (asl.df.ix[98, 1][features_ground]).tolist()
# .<ipython-input-17-1636f2224f9f>:11: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = (asl.df.ix[98, 1][features_norm]).tolist()
# .<ipython-input-17-1636f2224f9f>:15: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = (asl.df.ix[98,1][features_polar]).tolist()
# .
# ----------------------------------------------------------------------
# Ran 4 tests in 0.018s
#
# OK
# <unittest.runner.TextTestResult run=4 errors=0 failures=0>

# %% [markdown]
# <a id='part2_tutorial'></a>
# ## PART 2: Model Selection
# ### Model Selection Tutorial
# The objective of Model Selection is to tune the number of states for each word HMM prior to testing on unseen data.  In this section you will explore three methods:
# - Log likelihood using cross-validation folds (CV)
# - Bayesian Information Criterion (BIC)
# - Discriminative Information Criterion (DIC)

# %% [markdown]
# ##### Train a single word
# Now that we have built a training set with sequence data, we can "train" models for each word.  As a simple starting example, we train a single word using Gaussian hidden Markov models (HMM).   By using the `fit` method during training, the [Baum-Welch Expectation-Maximization](https://en.wikipedia.org/wiki/Baum%E2%80%93Welch_algorithm) (EM) algorithm is invoked iteratively to find the best estimate for the model *for the number of hidden states specified* from a group of sample seequences. For this example, we *assume* the correct number of hidden states is 3, but that is just a guess.  How do we know what the "best" number of states for training is?  We will need to find some model selection technique to choose the best parameter.

# %%
import warnings
from hmmlearn.hmm import GaussianHMM

def train_a_word(word, num_hidden_states, features):
    
    warnings.filterwarnings("ignore", category=DeprecationWarning)
    training = asl.build_training(features)  
    X, lengths = training.get_word_Xlengths(word)
    model = GaussianHMM(n_components=num_hidden_states, n_iter=1000).fit(X, lengths)
    logL = model.score(X, lengths)
    return model, logL

demoword = 'CHICAGO'
model, logL = train_a_word(demoword, 3, features_custom)
print("Number of states trained in model for {} is {}".format(demoword, model.n_components))
print("logL = {}".format(logL))
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Number of states trained in model for CHICAGO is 3
# logL = 25.984377819319434

# %% [markdown]
# The HMM model has been trained and information can be pulled from the model, including means and variances for each feature and hidden state.  The [log likelihood](http://math.stackexchange.com/questions/892832/why-we-consider-log-likelihood-instead-of-likelihood-in-gaussian-distribution) for any individual sample or group of samples can also be calculated with the `score` method.

# %%
def show_model_stats(word, model):
    print("Number of states trained in model for {} is {}".format(word, model.n_components))    
    variance=np.array([np.diag(model.covars_[i]) for i in range(model.n_components)])    
    for i in range(model.n_components):  # for each hidden state
        print("hidden state #{}".format(i))
        print("mean = ", model.means_[i])
        print("variance = ", variance[i])
        print()
    
show_model_stats(demoword, model)
# Out:
# Number of states trained in model for CHICAGO is 3
# hidden state #0
# mean =  [-0.66043038 -0.35312732 -1.10194388 -0.5603039 ]
# variance =  [0.05958665 0.06819926 0.00423575 0.0159287 ]
#
# hidden state #1
# mean =  [-1.1818332  -1.59542384 -0.62528245  0.25196334]
# variance =  [0.0199872  0.00484365 0.01763084 0.03617013]
#
# hidden state #2
# mean =  [-1.24472731 -1.10407496 -0.75712318 -0.45616375]
# variance =  [0.02675813 0.01335319 0.03002084 0.0106586 ]

# %% [markdown]
# ##### Try it!
# Experiment by changing the feature set, word, and/or num_hidden_states values in the next cell to see changes in values.

# %%
my_testword = 'CHICAGO'
model, logL = train_a_word(my_testword, 5, features_custom) # Experiment here with different parameters
show_model_stats(my_testword, model)
print("logL = {}".format(logL))
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Number of states trained in model for CHICAGO is 5
# hidden state #0
# mean =  [-1.05566441 -1.63198678 -0.73751759  0.42547804]
# variance =  [0.00813663 0.00650127 0.00977043 0.01141352]
#
# hidden state #1
# mean =  [-0.90138544 -0.63354237 -1.05983148 -0.63340298]
# variance =  [0.01131809 0.0643408  0.00518847 0.00824244]
#
# hidden state #2
# mean =  [-1.32939422 -1.15655324 -0.6684498  -0.42874601]
# variance =  [0.00808509 0.00724119 0.00977037 0.01141336]
#
# hidden state #3
# mean =  [-0.4162018  -0.13947282 -1.13465477 -0.44209626]
# variance =  [0.00942393 0.01580995 0.00529809 0.0051788 ]
#
# hidden state #4
# mean =  [-1.30799935 -1.55886168 -0.51304966  0.0784523 ]
# variance =  [0.00500135 0.0055124  0.00529837 0.00571337]
#
# logL = 48.6045332078271

# %% [markdown]
# ##### Visualize the hidden states
# We can plot the means and variances for each state and feature.  Try varying the number of states trained for the HMM model and examine the variances.  Are there some models that are "better" than others?  How can you tell?  We would like to hear what you think in the classroom online.

# %%
# %matplotlib inline

# %%
import math
from matplotlib import (cm, pyplot as plt, mlab)
from scipy.stats import norm 

def visualize(word, model):
    """ visualize the input model for a particular word """
    variance=np.array([np.diag(model.covars_[i]) for i in range(model.n_components)])
    figures = []
    for parm_idx in range(len(model.means_[0])):
        xmin = int(min(model.means_[:,parm_idx]) - max(variance[:,parm_idx]))
        xmax = int(max(model.means_[:,parm_idx]) + max(variance[:,parm_idx]))
        fig, axs = plt.subplots(model.n_components, sharex=True, sharey=False)
        colours = cm.rainbow(np.linspace(0, 1, model.n_components))
        for i, (ax, colour) in enumerate(zip(axs, colours)):
            x = np.linspace(xmin, xmax, 100)
            mu = model.means_[i,parm_idx]
            sigma = math.sqrt(np.diag(model.covars_[i])[parm_idx])
            ax.plot(x, norm.pdf(x, mu, sigma), c=colour)
            ax.set_title("{} feature {} hidden state #{}".format(word, parm_idx, i))

            ax.grid(True)
        figures.append(plt)
    for p in figures:
        p.show()
        
visualize(my_testword, model)

# %% [markdown]
# #####  ModelSelector class
# Review the `ModelSelector` class from the codebase found in the `my_model_selectors.py` module.  It is designed to be a strategy pattern for choosing different model selectors.  For the project submission in this section, subclass `SelectorModel` to implement the following model selectors.  In other words, you will write your own classes/functions in the `my_model_selectors.py` module and run them from this notebook:
#
# - `SelectorCV `:  Log likelihood with CV
# - `SelectorBIC`: BIC
# - `SelectorDIC`: DIC
#
# You will train each word in the training set with a range of values for the number of hidden states, and then score these alternatives with the model selector, choosing the "best" according to each strategy. The simple case of training with a constant value for `n_components` can be called using the provided `SelectorConstant` subclass as follow:

# %%
from my_model_selectors import SelectorConstant

training = asl.build_training(features_custom)  # Experiment here with different feature sets defined in part 1
word = 'CHICAGO' # Experiment here with different words
model = SelectorConstant(training.get_all_sequences(), training.get_all_Xlengths(), word, n_constant=3).select()
print("Number of states trained in model for {} is {}".format(word, model.n_components))
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Number of states trained in model for CHICAGO is 3

# %% [markdown]
# ##### Cross-validation folds
# If we simply score the model with the Log Likelihood calculated from the feature sequences it has been trained on, we should expect that more complex models will have higher likelihoods. However, that doesn't tell us which would have a better likelihood score on unseen data.  The model will likely be overfit as complexity is added.  To estimate which topology model is better using only the training data, we can compare scores using cross-validation.  One technique for cross-validation is to break the training set into "folds" and rotate which fold is left out of training.  The "left out" fold scored.  This gives us a proxy method of finding the best model to use on "unseen data". In the following example, a set of word sequences is broken into three folds using the [scikit-learn Kfold](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html) class object. When you implement `SelectorCV`, you will use this technique.

# %%
from sklearn.model_selection import KFold

training = asl.build_training(features_custom) # Experiment here with different feature sets
word = 'VEGETABLE' # Experiment here with different words
word_sequences = training.get_word_sequences(word)
#print(word_sequences)
split_method = KFold()
for cv_train_idx, cv_test_idx in split_method.split(word_sequences):
    print("Train fold indices:{} Test fold indices:{}".format(cv_train_idx, cv_test_idx))  # view indices of the folds
#    print("Combined train:", combine_sequences(cv_train_idx, word_sequences))
#    print("Combined test:", combine_sequences(cv_test_idx, word_sequences))
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Train fold indices:[2 3 4 5] Test fold indices:[0 1]
# Train fold indices:[0 1 3 4 5] Test fold indices:[2]
# Train fold indices:[0 1 2 4 5] Test fold indices:[3]
# Train fold indices:[0 1 2 3 5] Test fold indices:[4]
# Train fold indices:[0 1 2 3 4] Test fold indices:[5]

# %% [markdown]
# **Tip:** In order to run `hmmlearn` training using the X,lengths tuples on the new folds, subsets must be combined based on the indices given for the folds.  A helper utility has been provided in the `asl_utils` module named `combine_sequences` for this purpose.

# %% [markdown]
# ##### Scoring models with other criterion
# Scoring model topologies with **BIC** balances fit and complexity within the training set for each word.  In the BIC equation, a penalty term penalizes complexity to avoid overfitting, so that it is not necessary to also use cross-validation in the selection process.  There are a number of references on the internet for this criterion.  These [slides](http://www2.imm.dtu.dk/courses/02433/doc/ch6_slides.pdf) include a formula you may find helpful for your implementation.
#
# The advantages of scoring model topologies with **DIC** over BIC are presented by Alain Biem in this [reference](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.58.6208&rep=rep1&type=pdf) (also found [here](https://pdfs.semanticscholar.org/ed3d/7c4a5f607201f3848d4c02dd9ba17c791fc2.pdf)).  DIC scores the discriminant ability of a training set for one word against competing words.  Instead of a penalty term for complexity, it provides a penalty if model liklihoods for non-matching words are too similar to model likelihoods for the correct word in the word set.

# %% [markdown]
# <a id='part2_submission'></a>
# ### Model Selection Implementation Submission
# Implement `SelectorCV`, `SelectorBIC`, and `SelectorDIC` classes in the `my_model_selectors.py` module.  Run the selectors on the following five words. Then answer the questions about your results.
#
# **Tip:** The `hmmlearn` library may not be able to train or score all models.  Implement try/except contructs as necessary to eliminate non-viable models from consideration.

# %%
words_to_train = ['FISH', 'BOOK', 'VEGETABLE', 'FUTURE', 'JOHN', 'CHICAGO']
import timeit

# %%
# autoreload for automatically reloading changes made in my_model_selectors and my_recognizer
# %load_ext autoreload
# %autoreload 2

# %%
# TODO: Implement SelectorCV in my_model_selector.py
from my_model_selectors import SelectorCV

training = asl.build_training(features_custom)  # Experiment here with different feature sets defined in part 1
sequences = training.get_all_sequences()
Xlengths = training.get_all_Xlengths()
for word in words_to_train:
    start = timeit.default_timer()
    model = SelectorCV(sequences, Xlengths, word, 
                    min_n_components=2, max_n_components=15, random_state = 14).select()
    end = timeit.default_timer()-start
    if model is not None:
        X, lengths = training.get_word_Xlengths(word)
        logL = model.score(X, lengths)
        print("Training complete for {} with {} states with time {} seconds (logL = {})".format(word, model.n_components, end, logL))
    else:
        print("Training failed for {}".format(word))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 208 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (11). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 208 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (11). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 239 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (12). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 239 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 272 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (13). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 272 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 307 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 307 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 344 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 344 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 208 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (11). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Training complete for FISH with 11 states with time 0.8753210919999788 seconds (logL = 175.71050777030626)
# Training complete for BOOK with 2 states with time 5.267533027000013 seconds (logL = -81.88852341822636)
# Fitting a model with 208 free scalar parameters with only 204 data points will result in a degenerate solution.
# Fitting a model with 239 free scalar parameters with only 236 data points will result in a degenerate solution.
# Fitting a model with 239 free scalar parameters with only 204 data points will result in a degenerate solution.
# Fitting a model with 239 free scalar parameters with only 208 data points will result in a degenerate solution.
# Fitting a model with 272 free scalar parameters with only 236 data points will result in a degenerate solution.
# Fitting a model with 272 free scalar parameters with only 204 data points will result in a degenerate solution.
# Fitting a model with 272 free scalar parameters with only 208 data points will result in a degenerate solution.
# Fitting a model with 307 free scalar parameters with only 236 data points will result in a degenerate solution.
# Fitting a model with 307 free scalar parameters with only 204 data points will result in a degenerate solution.
# Fitting a model with 307 free scalar parameters with only 208 data points will result in a degenerate solution.
# Fitting a model with 344 free scalar parameters with only 236 data points will result in a degenerate solution.
# Fitting a model with 344 free scalar parameters with only 204 data points will result in a degenerate solution.
# Fitting a model with 344 free scalar parameters with only 208 data points will result in a degenerate solution.
# Training complete for VEGETABLE with 11 states with time 2.5867934890000015 seconds (logL = 539.0710426964547)
# Training complete for FUTURE with 2 states with time 4.29062499600002 seconds (logL = -192.05725241307817)
# Training complete for JOHN with 12 states with time 48.50577699399997 seconds (logL = 491.7415314113842)
# Training failed for CHICAGO

# %%
# TODO: Implement SelectorBIC in module my_model_selectors.py
from my_model_selectors import SelectorBIC

training = asl.build_training(features_custom)  # Experiment here with different feature sets defined in part 1
sequences = training.get_all_sequences()
Xlengths = training.get_all_Xlengths()
for word in words_to_train:
    start = timeit.default_timer()
    model = SelectorBIC(sequences, Xlengths, word, 
                    min_n_components=2, max_n_components=15, random_state = 14).select()
    end = timeit.default_timer()-start
    if model is not None:
        X, lengths = training.get_word_Xlengths(word)
        logL = model.score(X, lengths)
        print("Training complete for {} with {} states with time {} seconds (logL = {})".format(word, model.n_components, end, logL))
    else:
        print("Training failed for {}".format(word))
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Fitting a model with 104 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 208 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (11). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 239 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (12). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 272 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (13). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 307 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (14). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 344 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (15). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Training complete for FISH with 4 states with time 0.7547760130000256 seconds (logL = 195.20874036128328)
# Training complete for BOOK with 8 states with time 2.534880708000003 seconds (logL = 406.89675325729877)
# Fitting a model with 344 free scalar parameters with only 324 data points will result in a degenerate solution.
# Training complete for VEGETABLE with 9 states with time 1.2884727590000011 seconds (logL = 526.5834092171805)
# Training complete for FUTURE with 10 states with time 2.3939536810000277 seconds (logL = 197.8651677089532)
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# Training complete for JOHN with 15 states with time 31.860799482999994 seconds (logL = 1003.5199528463772)
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 208 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 239 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 272 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 307 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 344 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 208 free scalar parameters with only 44 data points will result in a degenerate solution.
# Training complete for CHICAGO with 11 states with time 0.39382497899998725 seconds (logL = 61.35476337034207)

# %%
# TODO: Implement SelectorDIC in module my_model_selectors.py
from my_model_selectors import SelectorDIC

training = asl.build_training(features_custom)  # Experiment here with different feature sets defined in part 1
sequences = training.get_all_sequences()
Xlengths = training.get_all_Xlengths()
for word in words_to_train:
    start = timeit.default_timer()
    model = SelectorDIC(sequences, Xlengths, word, 
                    min_n_components=2, max_n_components=15, random_state = 14).select()
    end = timeit.default_timer()-start
    if model is not None:
        X, lengths = training.get_word_Xlengths(word)
        logL = model.score(X, lengths)
        print("Training complete for {} with {} states with time {} seconds (logL = {})".format(word, model.n_components, end, logL))
    else:
        print("Training failed for {}".format(word))
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Fitting a model with 104 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 208 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (11). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 239 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (12). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 272 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (13). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 307 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (14). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 344 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (15). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Training complete for FISH with 2 states with time 3.0637592830000813 seconds (logL = 135.88277047738697)
# Training complete for BOOK with 12 states with time 4.336221943000055 seconds (logL = 502.0264830613103)
# Fitting a model with 344 free scalar parameters with only 324 data points will result in a degenerate solution.
# Training complete for VEGETABLE with 9 states with time 3.449171277000005 seconds (logL = 526.5834092171805)
# Training complete for FUTURE with 15 states with time 5.275655960999984 seconds (logL = 324.4191959852637)
# Training complete for JOHN with 15 states with time 33.14935657600006 seconds (logL = 1003.5199528463772)
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 208 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 239 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 272 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 307 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 344 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Training complete for CHICAGO with 6 states with time 1.9794817890000331 seconds (logL = 53.72754043009632)

# %% [markdown]
# **Question 2:**  Compare and contrast the possible advantages and disadvantages of the various model selectors implemented.
#
# **Answer 2:**
#
# BIC is performing training the fastest, owing to the simplicity of the computation for each choice of number of components considered. CV and DIC take noticeably more time, as for each choice additional computation is to be performed (different splits for CV, computation of the model's score for all other words for DIC).
#
# BIC is based on an _Occam’s razor principle_, that is, it selects the model that best fits the data. When solving the problem for a specific classification category, no information regarding other categories is taken into account.
#
# In constrast, DIC is based on _discriminative principle_, that is, the model found should not only fit the data from the selected category, but make sure that it clearly differentiates from other categories. For that purpose, the likelihood in the model of generating data from competing classes is also computed and counted against the model.
#
# As BIC is specifically penalizes the number of parameters, it is likely to be more useful in situations where we want to prevent overfitting, that is, when more data is available. We expect DIC to be more useful in opposite situations, that is, when there are lots of features to separate the data.

# %% [markdown]
# <a id='part2_test'></a>
# ### Model Selector Unit Testing
# Run the following unit tests as a sanity check on the implemented model selectors.  The test simply looks for valid interfaces  but is not exhaustive. However, the project should not be submitted if these tests don't pass.

# %%
from asl_test_model_selectors import TestSelectors
suite = unittest.TestLoader().loadTestsFromModule(TestSelectors())
unittest.TextTestRunner().run(suite)
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Fitting a model with 139 free scalar parameters with only 116 data points will result in a degenerate solution.
# ./Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# ./Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 31 free scalar parameters with only 30 data points will result in a degenerate solution.
# Fitting a model with 44 free scalar parameters with only 34 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 44 free scalar parameters with only 30 data points will result in a degenerate solution.
# Fitting a model with 59 free scalar parameters with only 34 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 59 free scalar parameters with only 30 data points will result in a degenerate solution.
# Fitting a model with 76 free scalar parameters with only 34 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 76 free scalar parameters with only 30 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 95 free scalar parameters with only 34 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 95 free scalar parameters with only 30 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 116 free scalar parameters with only 34 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 116 free scalar parameters with only 30 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 139 free scalar parameters with only 34 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 139 free scalar parameters with only 30 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# ./Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Fitting a model with 31 free scalar parameters with only 26 data points will result in a degenerate solution.
# Fitting a model with 44 free scalar parameters with only 26 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 59 free scalar parameters with only 26 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 76 free scalar parameters with only 26 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 95 free scalar parameters with only 26 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 116 free scalar parameters with only 26 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 139 free scalar parameters with only 26 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 31 free scalar parameters with only 26 data points will result in a degenerate solution.
# .
# ----------------------------------------------------------------------
# Ran 4 tests in 54.886s
#
# OK
# <unittest.runner.TextTestResult run=4 errors=0 failures=0>

# %% [markdown]
# <a id='part3_tutorial'></a>
# ## PART 3: Recognizer
# The objective of this section is to "put it all together".  Using the four feature sets created and the three model selectors, you will experiment with the models and present your results.  Instead of training only five specific words as in the previous section, train the entire set with a feature set and model selector strategy.
# ### Recognizer Tutorial
# ##### Train the full training set
# The following example trains the entire set with the example `features_ground` and `SelectorConstant` features and model selector.  Use this pattern for you experimentation and final submission cells.

# %%
from my_model_selectors import SelectorDIC
from my_model_selectors import SelectorBIC
from my_model_selectors import SelectorCV


def train_all_words(features, model_selector):
    training = asl.build_training(features)  # Experiment here with different feature sets defined in part 1
    sequences = training.get_all_sequences()
    Xlengths = training.get_all_Xlengths()
    model_dict = {}
    for word in training.words:
        model = model_selector(sequences, Xlengths, word, 
                        n_constant=3).select()
        model_dict[word]=model
    return model_dict

models = train_all_words(features_custom, SelectorDIC)
print("Number of word models returned = {}".format(len(models)))
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Fitting a model with 127 free scalar parameters with only 116 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 116 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 116 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 116 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 40 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (9) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 47 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 172 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 136 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 136 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 136 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 76 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 76 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 76 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (9) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 32 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 112 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 112 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 112 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 112 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 124 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 124 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 124 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 140 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 140 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 140 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 84 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 84 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 84 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 84 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 84 data points will result in a degenerate solution.
# Fitting a model with 19 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 48 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (9) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 36 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 36 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 152 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 152 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 47 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 36 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 132 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 132 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 36 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 36 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 156 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 156 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Number of word models returned = 112

# %% [markdown]
# ##### Load the test set
# The `build_test` method in `ASLdb` is similar to the `build_training` method already presented, but there are a few differences:
# - the object is type `SinglesData`
# - the internal dictionary keys are the index of the test word rather than the word itself
# - the getter methods are `get_all_sequences`, `get_all_Xlengths`, `get_item_sequences` and `get_item_Xlengths`

# %%
test_set = asl.build_test(features_delta)
print("Number of test set items: {}".format(test_set.num_items))
print("Number of test set sentences: {}".format(len(test_set.sentences_index)))
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:196: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = self.df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:198: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(self.df.ix[i,'startframe'], self.df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:200: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Number of test set items: 178
# Number of test set sentences: 40

# %% [markdown]
# <a id='part3_submission'></a>
# ### Recognizer Implementation Submission
# For the final project submission, students must implement a recognizer following guidance in the `my_recognizer.py` module.  Experiment with the four feature sets and the three model selection methods (that's 12 possible combinations). You can add and remove cells for experimentation or run the recognizers locally in some other way during your experiments, but retain the results for your discussion.  For submission, you will provide code cells of **only three** interesting combinations for your discussion (see questions below). At least one of these should produce a word error rate of less than 60%, i.e. WER < 0.60 .
#
# **Tip:** The hmmlearn library may not be able to train or score all models.  Implement try/except contructs as necessary to eliminate non-viable models from consideration.

# %%
# TODO implement the recognize method in my_recognizer
from my_recognizer import recognize
from asl_utils import show_errors

# %%
features_combined = features_norm + features_polar + features_ground + features_delta + features_custom

feature_choices = {
    'norm': features_norm, 
    'polar': features_polar, 
    'ground': features_ground, 
    'delta': features_delta, 
    'custom': features_custom, 
    'combined': features_combined
}

for fname, features in feature_choices.items():
    for model_selector in [SelectorCV, SelectorBIC, SelectorDIC]:
        models = train_all_words(features, model_selector)
        test_set = asl.build_test(features)
        probabilities, guesses = recognize(models, test_set)
        print('----------- For {} using model {}:'.format(fname, model_selector))
        show_errors(guesses, test_set)
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Fitting a model with 83 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 116 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 116 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 116 data points will result in a degenerate solution.
# Fitting a model with 19 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 148 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 112 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 112 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 144 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 112 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 144 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 28 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 60 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 136 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 136 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 156 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 172 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 80 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 80 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 80 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 108 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 80 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 108 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 64 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 64 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 19 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 28 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 47 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 28 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 28 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 28 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 56 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 56 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 56 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 56 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 56 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 56 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 88 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 88 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 92 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 88 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 92 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 47 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 76 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 176 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 47 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 48 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 48 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 48 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 48 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 48 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 48 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 56 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 24 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 56 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 56 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 56 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 56 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 56 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# ...
#   kmeans.fit(X)
# Fitting a model with 499 free scalar parameters with only 340 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 383 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 340 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 175 free scalar parameters with only 160 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 224 free scalar parameters with only 160 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 160 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 160 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 160 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 360 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 360 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 360 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 360 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 180 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 460 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 224 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 328 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 220 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 175 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 328 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 160 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 328 free scalar parameters with only 160 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 340 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 340 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 340 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:196: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = self.df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:198: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(self.df.ix[i,'startframe'], self.df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:200: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# ----------- For combined using model <class 'my_model_selectors.SelectorDIC'>:
#
# **** WER = 0.5112359550561798
# Total correct: 87 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#     2: JOHN *NEW *JOHN                                               JOHN WRITE HOMEWORK
#     7: JOHN *VISIT *ARRIVE CAN                                       JOHN CAN GO CAN
#    12: JOHN *WHAT *WHAT CAN                                          JOHN CAN GO CAN
#    21: JOHN *JOHN *JOHN *JOHN *CAR *CAR *FUTURE *FUTURE              JOHN FISH WONT EAT BUT CAN EAT CHICKEN
#    25: JOHN *MARY *LOVE IX *MARY                                     JOHN LIKE IX IX IX
#    28: JOHN *IX IX *MARY IX                                          JOHN LIKE IX IX IX
#    30: JOHN *MARY *MARY IX IX                                        JOHN LIKE IX IX IX
#    36: MARY *JOHN *IX IX *GO *JOHN                                   MARY VEGETABLE KNOW IX LIKE CORN1
#    40: JOHN *GIVE *CORN MARY *MARY                                   JOHN IX THINK MARY LOVE
#    43: JOHN *JOHN BUY HOUSE                                          JOHN MUST BUY HOUSE
#    50: *JOHN *SEE BUY CAR *JOHN                                      FUTURE JOHN BUY CAR SHOULD
#    54: JOHN *JOHN *JOHN BUY HOUSE                                    JOHN SHOULD NOT BUY HOUSE
#    57: JOHN *JOHN VISIT *IX                                          JOHN DECIDE VISIT MARY
#    67: JOHN FUTURE *MARY BUY HOUSE                                   JOHN FUTURE NOT BUY HOUSE
#    71: JOHN *JOHN *JOHN MARY                                         JOHN WILL VISIT MARY
#    74: *IX *VISIT VISIT MARY                                         JOHN NOT VISIT MARY
#    77: *JOHN BLAME MARY                                              ANN BLAME MARY
#    84: *LOVE *JOHN *CAR BOOK                                         IX-1P FIND SOMETHING-ONE BOOK
#    89: *MARY *JOHN *WOMAN *WOMAN IX NEW *BREAK-DOWN                  JOHN IX GIVE MAN IX NEW COAT
#    90: JOHN *IX IX *IX WOMAN BOOK                                    JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    92: JOHN *WOMAN IX *IX WOMAN BOOK                                 JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#   100: POSS NEW CAR BREAK-DOWN                                       POSS NEW CAR BREAK-DOWN
#   105: JOHN *POSS                                                    JOHN LEG
#   107: JOHN *JOHN *JOHN *IX *JOHN                                    JOHN POSS FRIEND HAVE CANDY
#   108: *JOHN *LOVE                                                   WOMAN ARRIVE
#   113: IX CAR *IX *MARY *JOHN                                        IX CAR BLUE SUE BUY
#   119: *MARY *BUY1 IX *JOHN *JOHN                                    SUE BUY IX CAR BLUE
#   122: JOHN *GIVE1 BOOK                                              JOHN READ BOOK
#   139: JOHN *BUY1 WHAT *JOHN BOOK                                    JOHN BUY WHAT YESTERDAY BOOK
#   142: JOHN BUY YESTERDAY WHAT BOOK                                  JOHN BUY YESTERDAY WHAT BOOK
#   158: LOVE JOHN *IX                                                 LOVE JOHN WHO
#   167: JOHN *JOHN *VISIT LOVE MARY                                   JOHN IX SAY LOVE MARY
#   171: JOHN MARY BLAME                                               JOHN MARY BLAME
#   174: *JOHN *GIVE1 GIVE1 *VISIT *JOHN                               PEOPLE GROUP GIVE1 JANA TOY
#   181: JOHN *JOHN                                                    JOHN ARRIVE
#   184: *IX BOY *GIVE1 TEACHER *GO                                    ALL BOY GIVE TEACHER APPLE
#   189: JOHN *IX *VISIT BOX                                           JOHN GIVE GIRL BOX
#   193: JOHN *GO *JOHN BOX                                            JOHN GIVE GIRL BOX
#   199: *JOHN *ARRIVE *MARY                                           LIKE CHOCOLATE WHO
#   201: JOHN *MAN *IX *WOMAN BUY HOUSE                                JOHN TELL MARY IX-1P BUY HOUSE

# %%
# Ground + CV
features = features_ground
model_selector = SelectorCV

# TODO Recognize the test set and display the result with the show_errors method
models = train_all_words(features, model_selector)
test_set = asl.build_test(features)
probabilities, guesses = recognize(models, test_set)
show_errors(guesses, test_set)
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 83 free scalar parameters with only 72 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 72 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 72 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 72 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 80 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 104 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 72 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 80 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 104 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 83 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 116 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 116 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 116 data points will result in a degenerate solution.
# Fitting a model with 19 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 16 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 47 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 24 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 148 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 64 free scalar parameters with only 48 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 48 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 48 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 48 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 48 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 88 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 112 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 88 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 112 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 88 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 144 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 112 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 88 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 144 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 28 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 32 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 64 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 83 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 92 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 136 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 136 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 156 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 172 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 80 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 80 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 108 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 80 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 108 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 80 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 108 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (9) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 83 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 64 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 64 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 64 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 64 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 19 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 28 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 28 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 28 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 64 free scalar parameters with only 56 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 83 free scalar parameters with only 56 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 56 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 56 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 56 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 56 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 128 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 128 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 128 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 128 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 128 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 88 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 92 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 88 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 92 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 88 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 92 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 88 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 92 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 47 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 64 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 83 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# ...
# Fitting a model with 83 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 60 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 60 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 48 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 48 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 48 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 48 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 48 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 48 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 64 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 96 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 96 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 100 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 96 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 60 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 100 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 96 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 136 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 136 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 136 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 176 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 136 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 104 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 112 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 112 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 112 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 100 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 148 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 83 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 80 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 127 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 80 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 152 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 80 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 179 free scalar parameters with only 76 data points will result in a degenerate solution.
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:196: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = self.df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:198: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(self.df.ix[i,'startframe'], self.df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:200: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# **** WER = 0.5561797752808989
# Total correct: 79 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#     2: *WHO *COAT *ARRIVE                                            JOHN WRITE HOMEWORK
#     7: JOHN *GO1 *HAVE *WHAT                                         JOHN CAN GO CAN
#    12: JOHN CAN *CAN CAN                                             JOHN CAN GO CAN
#    21: JOHN *VIDEOTAPE *JOHN *TELL *CAR *CAR EAT *BROTHER            JOHN FISH WONT EAT BUT CAN EAT CHICKEN
#    25: JOHN *TELL IX *TELL IX                                        JOHN LIKE IX IX IX
#    28: JOHN *TELL IX IX IX                                           JOHN LIKE IX IX IX
#    30: JOHN LIKE IX *MARY IX                                         JOHN LIKE IX IX IX
#    36: *WHO VEGETABLE *IX *GIVE *BILL *MARY                          MARY VEGETABLE KNOW IX LIKE CORN1
#    40: *JANA *BILL *FUTURE1 *JANA *IX                                JOHN IX THINK MARY LOVE
#    43: JOHN *SHOULD BUY HOUSE                                        JOHN MUST BUY HOUSE
#    50: *JOHN *SEE BUY CAR *ARRIVE                                    FUTURE JOHN BUY CAR SHOULD
#    54: JOHN SHOULD *FINISH BUY HOUSE                                 JOHN SHOULD NOT BUY HOUSE
#    57: *MARY *MARY *MARY *IX                                         JOHN DECIDE VISIT MARY
#    67: *IX *MOTHER NOT BUY HOUSE                                     JOHN FUTURE NOT BUY HOUSE
#    71: JOHN *FINISH *GIVE1 *GIVE1                                    JOHN WILL VISIT MARY
#    74: *IX *BILL *MARY MARY                                          JOHN NOT VISIT MARY
#    77: *JOHN BLAME *LOVE                                             ANN BLAME MARY
#    84: *LOVE *ARRIVE *GO *COAT                                       IX-1P FIND SOMETHING-ONE BOOK
#    89: *GIVE *GIVE GIVE *IX IX *ARRIVE COAT                          JOHN IX GIVE MAN IX NEW COAT
#    90: *POSS *ALL IX *IX WOMAN BOOK                                  JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    92: JOHN GIVE IX *IX WOMAN BOOK                                   JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#   100: POSS NEW CAR BREAK-DOWN                                       POSS NEW CAR BREAK-DOWN
#   105: JOHN *SEE                                                     JOHN LEG
#   107: JOHN *IX *ARRIVE *VISIT *JOHN                                 JOHN POSS FRIEND HAVE CANDY
#   108: *GIVE *LOVE                                                   WOMAN ARRIVE
#   113: IX CAR BLUE SUE *ARRIVE                                       IX CAR BLUE SUE BUY
#   119: *PREFER *BUY1 IX CAR *SUE                                     SUE BUY IX CAR BLUE
#   122: JOHN *HOUSE BOOK                                              JOHN READ BOOK
#   139: JOHN *BUY1 *CAN *VISIT BOOK                                   JOHN BUY WHAT YESTERDAY BOOK
#   142: JOHN *VIDEOTAPE YESTERDAY *TEACHER BOOK                       JOHN BUY YESTERDAY WHAT BOOK
#   158: LOVE *MARY *VEGETABLE                                         LOVE JOHN WHO
#   167: JOHN *SUE *BILL LOVE *LOVE                                    JOHN IX SAY LOVE MARY
#   171: JOHN *SUE BLAME                                               JOHN MARY BLAME
#   174: *WHAT *BLAME GIVE1 *APPLE *WHAT                               PEOPLE GROUP GIVE1 JANA TOY
#   181: JOHN ARRIVE                                                   JOHN ARRIVE
#   184: ALL *IX *GIVE1 TEACHER APPLE                                  ALL BOY GIVE TEACHER APPLE
#   189: *JANA *IX *APPLE *CAN                                         JOHN GIVE GIRL BOX
#   193: JOHN *ALL *YESTERDAY BOX                                      JOHN GIVE GIRL BOX
#   199: *LOVE CHOCOLATE *TELL                                         LIKE CHOCOLATE WHO
#   201: JOHN *SHOULD *GIVE *FRANK *ARRIVE HOUSE                       JOHN TELL MARY IX-1P BUY HOUSE

# %%
# Custom + BIC
features = features_custom
model_selector = SelectorBIC

# TODO Recognize the test set and display the result with the show_errors method
models = train_all_words(features, model_selector)
test_set = asl.build_test(features)
probabilities, guesses = recognize(models, test_set)
show_errors(guesses, test_set)
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Fitting a model with 127 free scalar parameters with only 116 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 116 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 116 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 116 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 40 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (9) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 47 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 96 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 172 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 60 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 96 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 136 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 136 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 76 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 76 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 76 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 76 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (9) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 32 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 88 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 112 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 112 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 112 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 28 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 124 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 124 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 124 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 124 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 140 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 140 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 84 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 84 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 84 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 84 data points will result in a degenerate solution.
# Fitting a model with 19 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 100 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 104 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 64 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 48 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 48 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (9) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 148 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 36 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 36 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 108 data points will result in a degenerate solution.
# Fitting a model with 32 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 24 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 40 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 152 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 83 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 104 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 127 free scalar parameters with only 32 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 47 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 36 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 132 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 132 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 72 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 36 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 152 free scalar parameters with only 36 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 179 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 36 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 52 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 92 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 128 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 44 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 156 data points will result in a degenerate solution.
# Fitting a model with 47 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 64 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 32 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 127 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 152 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 179 free scalar parameters with only 68 data points will result in a degenerate solution.
# Fitting a model with 104 free scalar parameters with only 68 data points will result in a degenerate solution.
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:196: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = self.df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:198: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(self.df.ix[i,'startframe'], self.df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:200: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# **** WER = 0.5730337078651685
# Total correct: 76 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#     2: JOHN *NEW *ARRIVE                                             JOHN WRITE HOMEWORK
#     7: JOHN *BUY GO CAN                                              JOHN CAN GO CAN
#    12: *IX CAN *NEW *WHAT                                            JOHN CAN GO CAN
#    21: JOHN *NEW *VISIT *VISIT *NEW *CAR *FUTURE *NEW                JOHN FISH WONT EAT BUT CAN EAT CHICKEN
#    25: JOHN *LOVE *LOVE *LOVE IX                                     JOHN LIKE IX IX IX
#    28: JOHN *GO *LOVE IX *LOVE                                       JOHN LIKE IX IX IX
#    30: JOHN LIKE *MARY *LIKE *MARY                                   JOHN LIKE IX IX IX
#    36: *JOHN *PREFER *GIVE IX *MARY *IX                              MARY VEGETABLE KNOW IX LIKE CORN1
#    40: JOHN *GO *VISIT MARY *MARY                                    JOHN IX THINK MARY LOVE
#    43: JOHN *MARY BUY HOUSE                                          JOHN MUST BUY HOUSE
#    50: *JOHN *PREFER BUY CAR *IX                                     FUTURE JOHN BUY CAR SHOULD
#    54: JOHN *FUTURE *MARY BUY HOUSE                                  JOHN SHOULD NOT BUY HOUSE
#    57: JOHN *PREFER *GO *LOVE                                        JOHN DECIDE VISIT MARY
#    67: *MARY *IX *EAT BUY HOUSE                                      JOHN FUTURE NOT BUY HOUSE
#    71: JOHN *FUTURE VISIT MARY                                       JOHN WILL VISIT MARY
#    74: JOHN *PREFER *LEAVE MARY                                      JOHN NOT VISIT MARY
#    77: ANN BLAME MARY                                                ANN BLAME MARY
#    84: *IX *NEW *ARRIVE *COAT                                        IX-1P FIND SOMETHING-ONE BOOK
#    89: *GIVE *GIVE *THROW *WOMAN IX NEW COAT                         JOHN IX GIVE MAN IX NEW COAT
#    90: *SELF *IX IX *IX *JOHN *VIDEOTAPE                             JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    92: JOHN *WOMAN IX *IX WOMAN BOOK                                 JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#   100: POSS NEW CAR BREAK-DOWN                                       POSS NEW CAR BREAK-DOWN
#   105: JOHN *SEE                                                     JOHN LEG
#   107: JOHN *JOHN FRIEND *MARY *SAY-1P                               JOHN POSS FRIEND HAVE CANDY
#   108: WOMAN *JOHN                                                   WOMAN ARRIVE
#   113: IX *NEW *IX *MARY *BUY1                                       IX CAR BLUE SUE BUY
#   119: *PREFER *LOVE *JOHN CAR *EAT                                  SUE BUY IX CAR BLUE
#   122: JOHN *GIVE1 BOOK                                              JOHN READ BOOK
#   139: JOHN *BUY1 WHAT *JOHN *VIDEOTAPE                              JOHN BUY WHAT YESTERDAY BOOK
#   142: JOHN *HAVE YESTERDAY WHAT *COAT                               JOHN BUY YESTERDAY WHAT BOOK
#   158: LOVE JOHN WHO                                                 LOVE JOHN WHO
#   167: JOHN *MARY *LEAVE LOVE *LOVE                                  JOHN IX SAY LOVE MARY
#   171: JOHN *IX BLAME                                                JOHN MARY BLAME
#   174: *CAR *NEW GIVE1 *VISIT *GO                                    PEOPLE GROUP GIVE1 JANA TOY
#   181: *SUE ARRIVE                                                   JOHN ARRIVE
#   184: *IX BOY *GIVE1 TEACHER *VISIT                                 ALL BOY GIVE TEACHER APPLE
#   189: JOHN *JOHN *NOT BOX                                           JOHN GIVE GIRL BOX
#   193: JOHN *NOT GIRL *WHAT                                          JOHN GIVE GIRL BOX
#   199: *JOHN *STUDENT *JOHN                                          LIKE CHOCOLATE WHO
#   201: *SOMETHING-ONE *GIVE *WOMAN *JOHN BUY HOUSE                   JOHN TELL MARY IX-1P BUY HOUSE

# %%
# Combined + DIC
features = features_combined
model_selector = SelectorDIC

# TODO Recognize the test set and display the result with the show_errors method
models = train_all_words(features, model_selector)
test_set = asl.build_test(features)
probabilities, guesses = recognize(models, test_set)
show_errors(guesses, test_set)
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 128 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 175 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 120 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 120 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 175 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 328 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 328 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 200 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 200 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 200 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 200 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 200 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 200 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 224 free scalar parameters with only 200 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 328 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 328 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 480 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 460 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 300 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 300 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 300 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 300 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 300 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 480 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 480 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 224 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 220 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 220 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 220 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 220 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 220 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (9) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 400 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 400 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 380 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 380 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 380 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 128 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 175 free scalar parameters with only 120 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 224 free scalar parameters with only 120 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 120 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 128 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 328 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 220 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 220 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 220 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 440 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 400 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 400 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 320 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 320 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 320 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 320 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 320 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 340 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 175 free scalar parameters with only 140 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 140 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 140 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 140 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 140 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 140 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 140 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 140 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 260 data points will result in a degenerate solution.
# Fitting a model with 328 free scalar parameters with only 260 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 260 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 260 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 260 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 420 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 420 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 420 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 128 free scalar parameters with only 80 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 175 free scalar parameters with only 80 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 224 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 328 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 80 data points will result in a degenerate solution.
# Fitting a model with 83 free scalar parameters with only 80 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 320 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 320 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 320 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 320 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 320 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 175 free scalar parameters with only 160 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 224 free scalar parameters with only 160 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 160 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 160 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 160 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 160 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 360 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 360 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 360 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 240 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 240 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 240 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 240 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 240 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 224 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 180 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 128 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 175 free scalar parameters with only 120 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 224 free scalar parameters with only 120 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 120 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 128 free scalar parameters with only 120 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 400 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 400 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 400 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 200 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 200 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 200 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 200 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 200 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 200 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 224 free scalar parameters with only 200 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 340 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 440 free scalar parameters with only 340 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 499 free scalar parameters with only 340 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 383 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 340 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 175 free scalar parameters with only 160 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 224 free scalar parameters with only 160 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 160 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 160 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 160 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 340 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 180 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 360 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 360 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 360 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 360 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 180 data points will result in a degenerate solution.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 180 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 275 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 328 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 260 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 460 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 224 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 328 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 440 free scalar parameters with only 220 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 220 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 175 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 224 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 275 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 328 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 383 free scalar parameters with only 160 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 499 free scalar parameters with only 160 data points will result in a degenerate solution.
# Fitting a model with 328 free scalar parameters with only 160 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 383 free scalar parameters with only 340 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 440 free scalar parameters with only 340 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 499 free scalar parameters with only 340 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:196: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = self.df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:198: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(self.df.ix[i,'startframe'], self.df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:200: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# **** WER = 0.5112359550561798
# Total correct: 87 out of 178
# Video  Recognized                                                    Correct
# =====================================================================================================
#     2: JOHN *NEW *JOHN                                               JOHN WRITE HOMEWORK
#     7: JOHN *VISIT *ARRIVE CAN                                       JOHN CAN GO CAN
#    12: JOHN *WHAT *WHAT CAN                                          JOHN CAN GO CAN
#    21: JOHN *JOHN *JOHN *JOHN *CAR *CAR *FUTURE *FUTURE              JOHN FISH WONT EAT BUT CAN EAT CHICKEN
#    25: JOHN *MARY *LOVE IX *MARY                                     JOHN LIKE IX IX IX
#    28: JOHN *IX IX *MARY IX                                          JOHN LIKE IX IX IX
#    30: JOHN *MARY *MARY IX IX                                        JOHN LIKE IX IX IX
#    36: MARY *JOHN *IX IX *GO *JOHN                                   MARY VEGETABLE KNOW IX LIKE CORN1
#    40: JOHN *GIVE *CORN MARY *MARY                                   JOHN IX THINK MARY LOVE
#    43: JOHN *JOHN BUY HOUSE                                          JOHN MUST BUY HOUSE
#    50: *JOHN *SEE BUY CAR *JOHN                                      FUTURE JOHN BUY CAR SHOULD
#    54: JOHN *JOHN *JOHN BUY HOUSE                                    JOHN SHOULD NOT BUY HOUSE
#    57: JOHN *JOHN VISIT *IX                                          JOHN DECIDE VISIT MARY
#    67: JOHN FUTURE *MARY BUY HOUSE                                   JOHN FUTURE NOT BUY HOUSE
#    71: JOHN *JOHN *JOHN MARY                                         JOHN WILL VISIT MARY
#    74: *IX *VISIT VISIT MARY                                         JOHN NOT VISIT MARY
#    77: *JOHN BLAME MARY                                              ANN BLAME MARY
#    84: *LOVE *JOHN *CAR BOOK                                         IX-1P FIND SOMETHING-ONE BOOK
#    89: *MARY *JOHN *WOMAN *WOMAN IX NEW *BREAK-DOWN                  JOHN IX GIVE MAN IX NEW COAT
#    90: JOHN *IX IX *IX WOMAN BOOK                                    JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#    92: JOHN *WOMAN IX *IX WOMAN BOOK                                 JOHN GIVE IX SOMETHING-ONE WOMAN BOOK
#   100: POSS NEW CAR BREAK-DOWN                                       POSS NEW CAR BREAK-DOWN
#   105: JOHN *POSS                                                    JOHN LEG
#   107: JOHN *JOHN *JOHN *IX *JOHN                                    JOHN POSS FRIEND HAVE CANDY
#   108: *JOHN *LOVE                                                   WOMAN ARRIVE
#   113: IX CAR *IX *MARY *JOHN                                        IX CAR BLUE SUE BUY
#   119: *MARY *BUY1 IX *JOHN *JOHN                                    SUE BUY IX CAR BLUE
#   122: JOHN *GIVE1 BOOK                                              JOHN READ BOOK
#   139: JOHN *BUY1 WHAT *JOHN BOOK                                    JOHN BUY WHAT YESTERDAY BOOK
#   142: JOHN BUY YESTERDAY WHAT BOOK                                  JOHN BUY YESTERDAY WHAT BOOK
#   158: LOVE JOHN *IX                                                 LOVE JOHN WHO
#   167: JOHN *JOHN *VISIT LOVE MARY                                   JOHN IX SAY LOVE MARY
#   171: JOHN MARY BLAME                                               JOHN MARY BLAME
#   174: *JOHN *GIVE1 GIVE1 *VISIT *JOHN                               PEOPLE GROUP GIVE1 JANA TOY
#   181: JOHN *JOHN                                                    JOHN ARRIVE
#   184: *IX BOY *GIVE1 TEACHER *GO                                    ALL BOY GIVE TEACHER APPLE
#   189: JOHN *IX *VISIT BOX                                           JOHN GIVE GIRL BOX
#   193: JOHN *GO *JOHN BOX                                            JOHN GIVE GIRL BOX
#   199: *JOHN *ARRIVE *MARY                                           LIKE CHOCOLATE WHO
#   201: JOHN *MAN *IX *WOMAN BUY HOUSE                                JOHN TELL MARY IX-1P BUY HOUSE

# %% [markdown]
# **Question 3:**  Summarize the error results from three combinations of features and model selectors.  What was the "best" combination and why?  What additional information might we use to improve our WER?  For more insight on improving WER, take a look at the introduction to Part 4.
#
# **Answer 3:**
#
# First we provide the WER from the run of all of the feature sets with all of the selection methods:
#
# | Feature set         |      CV   |     BIC   |     DIC   | minimum |
# | ------------------- |:---------:|:---------:|:---------:|:-------:|
# | `features_norm`     | **0.601** |  0.617    |  0.623    |  0.601  |
# | `features_polar`    |  0.578    |  0.550    | **0.544** |  0.544  |
# | `features_ground`   | **0.533** |  0.556    |  0.578    |  0.533  |
# | `features_delta`    | **0.623** |  0.634    |  0.657    |  0.623  |
# | `features_custom`   |  0.601    | **0.589** |  0.601    |  0.589  |
# | `features_combined` | **0.505** |  0.533    | **0.505** |**0.505**|
#
# We obtain the best classification results from using combined features with CV or DIC selection method.
#
# There are several conclusions that we can make from these experimental results:
#
# 1. That we get the best classification results by using the most features is unsurprising. Of course, having more features increases the amount of resourses necessary for the computation, so this would present an important tradeoff in practice.
# 1. Taken by themselves, `polar` and `ground` feature sets perform the best, while `custom` set does not quite fulfill the high expectations and is located in the middle of the pack. It is easy to explain why the remaning two feature sets have worse results: they doesn't even take into account the nose position.
# 1. There is no single selection method that would be the best choice for all feature sets. Note that from Part 2 we learned that DIC and CV methods took more time to select the model. As predicted, DIC seems to be more suited for the case of many features (where overfitting is less likely) compared to BIC.
#
# We have provided in the separate cells the runs details for the specific combinations of
#
# - Ground + CV
# - Custom + BIC
# - Combined + DIC
#
# All of them give the error rate of less than 60%. Examining the mistakes themselves we see that some words, like `JOHN`, are recognized correctly by all of the three, as well as that some videos, like 21, provide a high recognition challenge.
#
# Even the best method, however, makes guesses that are clearly nonsense, such as `JOHN FUTURE FUTURE BUY HOUSE`. We know that the repetition `FUTURE FUTURE BUY` is very unlikely, but the model doesn't take into account this information. We should be able to improve our accuracy further by taking the context of the words into account.
#
# Specifically, we can use the notion of an _n-gram SLM_, where our approach so far was equivalent to a _0-gram SLM_. Saving the data on 1-gram, or even better, bigram, probabilities should already help us to cut down the nonsensical guesses, like `FUTURE FUTURE BUY`, in favor of correct guesses, like `FUTURE NOT BUY`.

# %% [markdown]
# <a id='part3_test'></a>
# ### Recognizer Unit Tests
# Run the following unit tests as a sanity check on the defined recognizer.  The test simply looks for some valid values but is not exhaustive. However, the project should not be submitted if these tests don't pass.

# %%
from asl_test_recognizer import TestRecognize
suite = unittest.TestLoader().loadTestsFromModule(TestRecognize())
unittest.TextTestRunner().run(suite)
# Out:
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:196: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = self.df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:198: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(self.df.ix[i,'startframe'], self.df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:200: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Fitting a model with 20 free scalar parameters with only 12 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 18 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 18 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 18 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 12 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 14 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 8 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 20 free scalar parameters with only 16 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 20 free scalar parameters with only 18 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 20 free scalar parameters with only 12 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 20 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 18 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 18 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 16 data points will result in a degenerate solution.
# ./Users/in/Code/aind/AIND-Recognizer/asl_data.py:103: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   word = tr_df.ix[i,'word']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:104: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = tr_df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:106: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(tr_df.ix[i,'startframe'], tr_df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:108: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:196: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   video = self.df.ix[i,'video']
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:198: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   for frame in range(self.df.ix[i,'startframe'], self.df.ix[i,'endframe']+1):
# /Users/in/Code/aind/AIND-Recognizer/asl_data.py:200: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   sample = [asl.df.ix[vid_frame][f] for f in feature_list]
# Fitting a model with 20 free scalar parameters with only 12 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 18 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 18 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 18 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 12 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 14 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 8 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 20 free scalar parameters with only 16 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 20 free scalar parameters with only 18 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Fitting a model with 20 free scalar parameters with only 12 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/hmmlearn/hmm.py:217: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   kmeans.fit(X)
# Fitting a model with 20 free scalar parameters with only 16 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 18 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 18 data points will result in a degenerate solution.
# Fitting a model with 20 free scalar parameters with only 16 data points will result in a degenerate solution.
# .
# ----------------------------------------------------------------------
# Ran 2 tests in 31.372s
#
# OK
# <unittest.runner.TextTestResult run=2 errors=0 failures=0>

# %% [markdown]
# <a id='part4_info'></a>
# ## PART 4: (OPTIONAL)  Improve the WER with Language Models
# We've squeezed just about as much as we can out of the model and still only get about 50% of the words right! Surely we can do better than that.  Probability to the rescue again in the form of [statistical language models (SLM)](https://en.wikipedia.org/wiki/Language_model).  The basic idea is that each word has some probability of occurrence within the set, and some probability that it is adjacent to specific other words. We can use that additional information to make better choices.
#
# ##### Additional reading and resources
# - [Introduction to N-grams (Stanford Jurafsky slides)](https://web.stanford.edu/class/cs124/lec/languagemodeling.pdf)
# - [Speech Recognition Techniques for a Sign Language Recognition System, Philippe Dreuw et al](https://www-i6.informatik.rwth-aachen.de/publications/download/154/Dreuw--2007.pdf) see the improved results of applying LM on *this* data!
# - [SLM data for *this* ASL dataset](ftp://wasserstoff.informatik.rwth-aachen.de/pub/rwth-boston-104/lm/)
#
# ##### Optional challenge
# The recognizer you implemented in Part 3 is equivalent to a "0-gram" SLM.  Improve the WER with the SLM data provided with the data set in the link above using "1-gram", "2-gram", and/or "3-gram" statistics. The `probabilities` data you've already calculated will be useful and can be turned into a pandas DataFrame if desired (see next cell).
# Good luck!  Share your results with the class!

# %%
# create a DataFrame of log likelihoods for the test word items
df_probs = pd.DataFrame(data=probabilities)
df_probs.head()
# Out:
#           JOHN         WRITE      HOMEWORK          IX-1P           SEE  \
# 0  -423.204939 -8.429863e+05  -9002.557588   -6208.929967  -3962.639113
# 1  -734.101489 -5.462022e+05  -3048.703916 -102359.715738 -79941.491353
# 2 -1358.996940 -5.065979e+05  -2398.412330 -120793.061867 -90116.517787
# 3  -341.249208 -5.263531e+06 -25803.705022  -59339.342650 -19282.321755
# 4  -296.043929 -1.007301e+06  -5061.980023  -32914.141462 -15869.159895
#
#      YESTERDAY           IX         LOVE         MARY          CAN  ...  \
# 0 -1411.979153  -704.135982 -1347.711038  -626.429244 -3868.659630  ...
# 1 -2755.463447 -3203.946208 -1151.695742 -1031.532575 -1422.562969  ...
# 2 -4579.228924 -4663.054282 -2802.524542 -1906.244243 -2269.387687  ...
# 3 -2639.138322  -566.426381 -1837.258730  -592.159498 -4147.879683  ...
# 4 -1337.367273 -1289.738181  -717.231990  -508.293364  -319.239217  ...
#
#              TOY           ALL           BOY       TEACHER          GIRL  \
# 0 -242284.749192 -4.787973e+05 -10082.983682 -13684.433820  -9453.282821
# 1 -363120.181789 -1.578732e+06 -12763.046906  -3123.728467 -91866.602023
# 2 -608009.810531 -2.315412e+06 -20817.154953  -6352.931684 -60406.943491
# 3 -546923.939798 -1.017512e+05  -8530.605645 -24046.720413  -5745.587817
# 4  -42897.348178 -4.642872e+05  -4344.945605  -1743.715872 -41632.961322
#
#            BOX         GIVE2         GIVE3           GET       PUTASIDE
# 0 -4624.766100 -2.549596e+07 -16442.549873 -1.629722e+06 -169182.547418
# 1 -2246.522069 -8.349179e+07  -2510.377470 -1.843378e+06 -696907.374393
# 2 -4777.103182 -1.195257e+08  -9354.181186 -3.458152e+06 -955119.723093
# 3 -3665.024283 -2.228739e+05 -18646.472396 -1.016340e+07 -383147.389074
# 4  -471.184742 -1.379690e+07  -1947.107113 -1.085282e+06 -231259.685108
#
# [5 rows x 112 columns]
